# %%
import torch
import torch.nn as nn
from torchvision import models
import numpy as np
import cv2
import torch.nn.functional as F
import torchvision

# %%
from net_fast.unet_model import UNet 
device = 'cuda:2' if torch.cuda.is_available() else 'cpu'

# %%
model = UNet(n_channels=3,n_classes=3)
# model.load_state_dict(torch.load('unet3.pt'))
model.to(device)
model.eval()
# Out:
# UNet(
#   (inc): inconv(
#     (conv): double_conv_in(
#       (conv): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace)
#         (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#         (3): ReLU(inplace)
#       )
#     )
#   )
#   (down1): down(
#     (mpconv): Sequential(
#       (0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (1): double_conv(
#         (conv): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#           (1): GroupNorm(64, 128, eps=1e-05, affine=True)
#           (2): shuffle()
#           (3): ReLU(inplace)
#           (4): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64)
#           (5): GroupNorm(64, 128, eps=1e-05, affine=True)
#           (6): shuffle()
#           (7): ReLU(inplace)
#         )
#       )
# ...

# %%
ToTensor = torchvision.transforms.Compose([torchvision.transforms.ToTensor()])

# %%
import time
from torchvision.utils import make_grid

# %%
cap = cv2.VideoCapture('01TP_extract.avi')
n_iter = 0
with torch.no_grad():
    while(True):
        start = torch.cuda.Event(enable_timing=True)
        end = torch.cuda.Event(enable_timing=True)

        



        # Waits for everything to finish running
        

        
        # Capture frame-by-frame
        ret, frame = cap.read()
        
        # Our operations on the frame come here
    #     print(frame.shape)
        tic = time.clock()
        start.record()
        frame = ToTensor(frame).unsqueeze(0).to(device)
        end.record()
        torch.cuda.synchronize()
        print(start.elapsed_time(end))
        toc = time.clock()
        
        out = model(frame)
        
        
        
        
#         x = make_grid(out, normalize=True, scale_each=True)
#         writer.add_image('Image', x, n_iter)
#         y = make_grid(frame, normalize=True, scale_each=True)
#         writer.add_image('Original', y, n_iter)
#         print(toc - tic)
        n_iter = n_iter+1
# Out:
# 13.165568351745605
# 89.10131072998047
# 87.6728286743164
# 84.88345336914062
# 86.81574249267578
# 82.02035522460938
# 83.04025268554688
# 85.18348693847656
# 84.27008056640625
# 84.37964630126953
# 84.44825744628906
# 82.8190689086914
# 82.68287658691406
# 85.47942352294922
# 85.28691101074219
# 83.54508972167969
# 83.22662353515625
# 85.70982360839844
# 83.5962905883789
# 83.96492767333984
# 84.06425476074219
# 83.53075408935547
# 82.86617279052734
# 85.83372497558594
# 84.96332550048828
# 83.19692993164062
# 85.35858917236328
# 82.03059387207031
# 83.16620635986328
# 83.33106994628906
# 85.24697875976562
# 83.24505615234375
# 82.62451171875
# 85.89926147460938
# 85.7712631225586
# 83.63929748535156
# 85.06060791015625
# 84.04684448242188
# 82.42483520507812
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-b1fe1f90bd22> in <module>
# ...
